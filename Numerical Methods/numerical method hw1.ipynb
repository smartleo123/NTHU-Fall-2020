# %%
# import common used packages
# %matplotlib inline
from sklearn import datasets
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = datasets.load_iris()
x = pd.DataFrame(iris['data'], columns=iris['feature_names'])
print("target_names: "+str(iris['target_names']))
y = pd.DataFrame(iris['target'], columns=['target'])
iris_data = pd.concat([x,y], axis=1)
iris_data.head(5)
# Out:
# target_names: ['setosa' 'versicolor' 'virginica']
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
iris_data[50:54]
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
#
#     target
# 50       1
# 51       1
# 52       1
# 53       1

# %%
iris_data.tail(5)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2

# %%
target_name = {
    0:'setosa',
    1:'versicolor',
    2:'virginica'
}

iris_data['target_name'] = iris_data['target'].map(target_name)
iris_data = iris_data[(iris_data['target_name'] == 'setosa')|(iris_data['target_name'] == 'versicolor')]
iris_data = iris_data[['sepal length (cm)','sepal width (cm)','target_name']]
iris_data.head(5)
# Out:
#    sepal length (cm)  sepal width (cm) target_name
# 0                5.1               3.5      setosa
# 1                4.9               3.0      setosa
# 2                4.7               3.2      setosa
# 3                4.6               3.1      setosa
# 4                5.0               3.6      setosa

# %%
iris_data.tail(5)
# Out:
#     sepal length (cm)  sepal width (cm) target_name
# 95                5.7               3.0  versicolor
# 96                5.7               2.9  versicolor
# 97                6.2               2.9  versicolor
# 98                5.1               2.5  versicolor
# 99                5.7               2.8  versicolor

# %%
target_class = {
    'setosa':1,
    'versicolor':-1
}
iris_data['target_class'] = iris_data['target_name'].map(target_class)
del iris_data['target_name']
iris_data.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  target_class
# 0                5.1               3.5             1
# 1                4.9               3.0             1
# 2                4.7               3.2             1
# 3                4.6               3.1             1
# 4                5.0               3.6             1

# %%
def sign(x):
    if x > 0:
        return 1
    else:
        return -1

# %% [markdown]
# ## The iteration below can't stop, it is clear that we couln't separate setosa and  versicolor through sepal length and sepal witdth.
#
# ## The intuitive reason I can imagine is that there is correlation between those two variables I have chosen

# %%
w = np.array([0.,0.,0.])
error = 1
iterator = 0
while error != 0:
    error = 0
    for i in range(len(iris_data)):
        x,y = np.concatenate((np.array([1.]), np.array(iris_data.iloc[i])[:2])), np.array(iris_data.iloc[i])[2]
        if sign(np.dot(w,x)) != y:
            print("iterator: "+str(iterator))
            iterator += 1
            error += 1
            sns.lmplot('sepal length (cm)','sepal width (cm)',data=iris_data, fit_reg=False, hue ='target_class')
            
            # in order to renew the boundary
            w += y*x                       
            print("w: " + str(w))
            
            # Decision boundary 
            x_decision_boundary = np.linspace(-0.5,7)
            y_decision_boundary = (-w[1]/w[2])*x_decision_boundary - (w[0]/w[2])
            plt.plot(x_decision_boundary, y_decision_boundary,'r')
# Out:
# iterator: 0
# w: [1.  5.1 3.5]
# iterator: 1
# w: [ 0.  -1.9  0.3]
# iterator: 2
# w: [1.  3.2 3.8]
# iterator: 3
# w: [ 0.  -3.8  0.6]
# iterator: 4
# w: [1.  1.3 4.1]
# iterator: 5
# w: [ 0.  -5.7  0.9]
# iterator: 6
# w: [ 1.  -0.6  4.4]
# iterator: 7
# w: [ 0.  -7.6  1.2]
# iterator: 8
# w: [ 1.  -2.5  4.7]
# iterator: 9
# w: [ 0.  -8.9  1.5]
# iterator: 10
# w: [ 1.  -3.8  5. ]
# iterator: 11
# w: [2.  1.1 8. ]
# iterator: 12
# w: [ 1.  -5.9  4.8]
# iterator: 13
# w: [ 2.  -0.8  8.3]
# iterator: 14
# w: [ 1.  -7.8  5.1]
# iterator: 15
# w: [ 2.  -2.7  8.6]
# iterator: 16
# w: [ 1.  -9.7  5.4]
# iterator: 17
# w: [ 2.  -4.6  8.9]
# iterator: 18
# w: [  1.  -11.    5.7]
# iterator: 19
# w: [ 2.  -5.9  9.2]
# iterator: 20
# w: [ 3.  -1.4 11.5]
# iterator: 21
# ...

# %% [markdown]
# ## I repeat the works again to observe how different variables would affect the outcome

# %%
iris = datasets.load_iris()
x = pd.DataFrame(iris['data'], columns=iris['feature_names'])
y = pd.DataFrame(iris['target'], columns=['target'])
iris_data = pd.concat([x,y], axis=1)

# %%
target_name = {
    0:'setosa',
    1:'versicolor',
    2:'virginica'
}

iris_data['target_name'] = iris_data['target'].map(target_name)
iris_data = iris_data[(iris_data['target_name'] == 'setosa')|(iris_data['target_name'] == 'versicolor')]
iris_data = iris_data[['sepal length (cm)','petal length (cm)','target_name']]

# %%
target_class = {
    'setosa':1,
    'versicolor':-1
}
iris_data['target_class'] = iris_data['target_name'].map(target_class)
del iris_data['target_name']
iris_data.head(5)
# Out:
#    sepal length (cm)  petal length (cm)  target_class
# 0                5.1                1.4             1
# 1                4.9                1.4             1
# 2                4.7                1.3             1
# 3                4.6                1.5             1
# 4                5.0                1.4             1

# %% [markdown]
# ## Fortunately, I am able to separate them this time !
# ## It takes 9 iterations to separate them, I wonder whether I could do it with less iterations.

# %%
w = np.array([0.,0.,0.])
error = 1
iterator = 0
while error != 0:
    error = 0
    for i in range(len(iris_data)):
        x,y = np.concatenate((np.array([1.]), np.array(iris_data.iloc[i])[:2])), np.array(iris_data.iloc[i])[2]
        if sign(np.dot(w,x)) != y:
            print("iterator: "+str(iterator))
            iterator += 1
            error += 1
            sns.lmplot('sepal length (cm)','petal length (cm)',data=iris_data, fit_reg=False, hue ='target_class')
            
            # in order to renew the boundary
            w += y*x                       
            print("w: " + str(w))
            
            # Decision boundary 
            x_decision_boundary = np.linspace(-0.5,7)
            y_decision_boundary = (-w[1]/w[2])*x_decision_boundary - (w[0]/w[2])
            plt.plot(x_decision_boundary, y_decision_boundary,'r')
# Out:
# iterator: 0
# w: [1.  5.1 1.4]
# iterator: 1
# w: [ 0.  -1.9 -3.3]
# iterator: 2
# w: [ 1.   3.2 -1.9]
# iterator: 3
# w: [ 0.  -3.8 -6.6]
# iterator: 4
# w: [ 1.   1.3 -5.2]
# iterator: 5
# w: [ 2.   5.9 -3.7]
# iterator: 6
# w: [ 1.  -1.1 -8.4]
# iterator: 7
# w: [ 2.  4. -7.]
# iterator: 8
# w: [  1.   -1.7 -10.5]
# iterator: 9
# w: [ 2.   3.4 -9.1]

# %% [markdown]
# ## This is the third time I repeat my work

# %%
iris = datasets.load_iris()
x = pd.DataFrame(iris['data'], columns=iris['feature_names'])
y = pd.DataFrame(iris['target'], columns=['target'])
iris_data = pd.concat([x,y], axis=1)

# %%
target_name = {
    0:'setosa',
    1:'versicolor',
    2:'virginica'
}

iris_data['target_name'] = iris_data['target'].map(target_name)
iris_data = iris_data[(iris_data['target_name'] == 'setosa')|(iris_data['target_name'] == 'versicolor')]
iris_data = iris_data[['sepal width (cm)','petal width (cm)','target_name']]

# %%
target_class = {
    'setosa':1,
    'versicolor':-1
}
iris_data['target_class'] = iris_data['target_name'].map(target_class)
del iris_data['target_name']
iris_data.head(5)
# Out:
#    sepal width (cm)  petal width (cm)  target_class
# 0               3.5               0.2             1
# 1               3.0               0.2             1
# 2               3.2               0.2             1
# 3               3.1               0.2             1
# 4               3.6               0.2             1

# %% [markdown]
# ## It only takes two iterations this time.
# ## It seems that choosing the correct variables is the most important work in the task of perceptron.

# %%
w = np.array([0.,0.,0.])
error = 1
iterator = 0
while error != 0:
    error = 0
    for i in range(len(iris_data)):
        x,y = np.concatenate((np.array([1.]), np.array(iris_data.iloc[i])[:2])), np.array(iris_data.iloc[i])[2]
        if sign(np.dot(w,x)) != y:
            print("iterator: "+str(iterator))
            iterator += 1
            error += 1
            sns.lmplot('sepal width (cm)','petal width (cm)',data=iris_data, fit_reg=False, hue ='target_class')
            
            # in order to renew the boundary
            w += y*x                       
            print("w: " + str(w))
            
            # Decision boundary 
            x_decision_boundary = np.linspace(-0.5,7)
            y_decision_boundary = (-w[1]/w[2])*x_decision_boundary - (w[0]/w[2])
            plt.plot(x_decision_boundary, y_decision_boundary,'r')
# Out:
# iterator: 0
# w: [1.  3.5 0.2]
# iterator: 1
# w: [ 0.   0.3 -1.2]
